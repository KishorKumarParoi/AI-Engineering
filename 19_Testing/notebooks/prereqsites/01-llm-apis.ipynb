# %%
from dotenv import load_dotenv
import os

# %%
print("Loading environment variables from .env file...")
# Out:
# Loading environment variables from .env file...

# %%
# %pwd
# Out:
# '/Users/kishorkumarparoi/Desktop/Maven - The AI Engineering Bootcamp /Resources/AIE5-main/19_Testing/notebooks/prereqsites'

# %%
load_dotenv("../../.env")
# Out:
# True

# %%
# %pwd
# Out:
# '/Users/kishorkumarparoi/Desktop/Maven - The AI Engineering Bootcamp /Resources/AIE5-main/19_Testing/notebooks/prereqsites'

# %% [markdown]
# Open AI Code

# %%
import openai 

response = openai.chat.completions.create(
   model="gpt-5-nano",
   messages=[
       {"role": "system", "content": "You are a helpful assistant."},
       {"role": "user", "content": "What is the capital of France?"}
   ]
)

print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# Gemini Code

# %%
from google import genai
gemini_client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
   contents=[
       "You are a helpful assistant.",
       "What is the capital of France?"
   ]
)

print(response.text)
# Out:
# The capital of France is **Paris**.

# %%
response.usage_metadata
# Out:
# GenerateContentResponseUsageMetadata(
#   candidates_token_count=8,
#   prompt_token_count=14,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=14
#     ),
#   ],
#   thoughts_token_count=26,
#   total_token_count=48
# )

# %% [markdown]
# Groq Code

# %%
from groq import Groq
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"}
    ],
    model="llama-3.3-70b-versatile"
)

print(response.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=8, prompt_tokens=48, total_tokens=56, completion_time=0.010939213, completion_tokens_details=None, prompt_time=0.002227982, prompt_tokens_details=None, queue_time=0.056101947, total_time=0.013167195)

# %% [markdown]
# Deepseek Code

# %%
from deepseek import DeepSeekAPI
import os

client = DeepSeekAPI(api_key=os.getenv("DEEPSEEK_API_KEY"))

response = client.chat_completion(
    prompt="What is the capital of France?",
    model="deepseek-chat"
)

print(response)
